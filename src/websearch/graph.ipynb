# %%
import sys

sys.path.append("/home/vertefra/Desktop/spending-app/websearch/src")

from graph import graph
from IPython.display import Image, display
display(Image(graph.get_graph().draw_mermaid_png()))
# Out:
# 2025-03-30 10:12:20,624 - root - INFO - Root logger is set up.
# 2025-03-30 10:12:20,864 - websearch.modelcontext - INFO - Context: AppContext(provider=ollama, model=qwen2.5:7b, base_url=http://localhost:11434/v1)
